# %% [markdown]
# # Gradient descent

# %% [markdown]
# What is a Cost Function?
# It is a function that measures the performance of a model for any given data. Cost Function quantifies the error between predicted values and expected values and presents it in the form of a single real number.
#
#
# Gadient descent is an iterative optimization algorithm for finding the local minimum of a function.
#
# To find the local minimum of a function using gradient descent, we must take steps proportional to the negative of the gradient (move away from the gradient) of the function at the current point. If we take steps proportional to the positive of the gradient (moving towards the gradient), we will approach a local maximum of the function, and the procedure is called Gradient Ascent.

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

x, y = make_regression(n_samples = 100, n_features = 1, n_informative = 1, n_targets = 1, noise = 80, random_state = 5)

# %%
plt.figure(figsize = (16, 8))
plt.scatter(x, y, color = "seagreen")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

LinReg = LinearRegression()
LinReg.fit(x, y)
# Out:
# LinearRegression()

# %%
LinReg.coef_
# Out:
# array([58.63420764])

# %%
LinReg.intercept_
# Out:
# 13.09361138321335

# %%
ypred = LinReg.predict(x)

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.plot(x, ypred, color = "red", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "OLS")
plt.legend()
plt.show()

# %%
# Lets apply Gradient Descent assuming slope is constant m = 58.63420764
# and let's assume the starting value for intercept b = 0
ypred1 = ((58.63420764 * x) + 0).ravel()

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.plot(x, ypred, color = "red", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "OLS")
plt.plot(x ,ypred1, color = "black", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "b = 0")
plt.legend()
plt.show()

# %%
m = 58.63420764
b = 0

loss_slope = -2 * (np.sum(y - (m*x.ravel() - b)))
loss_slope
# Out:
# -2618.7222766389636

# %%
# Lets take learning rate = 0.1
lr = 0.001

step_size = loss_slope * lr
step_size
# Out:
# -2.6187222766389637

# %%
b1 = b - step_size
b1
# Out:
# 2.6187222766389637

# %%
ypred2 = ((58.63420764 * x) + b1).ravel()

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.plot(x, ypred, color = "red", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "OLs")
plt.plot(x ,ypred1, color = "black", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = 'b = 0')
plt.plot(x ,ypred2, color = "blue", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b))

plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * (np.sum(y - (m * x.ravel() - b1)))
loss_slope
# Out:
# -3142.4667319667565

# %%
step_size = loss_slope * lr
step_size
# Out:
# -3.1424667319667567

# %%
b2 = b1 - step_size
b2
# Out:
# 5.7611890086057205

# %%
ypred3 = ((58.63420764 * x) + b2).ravel()

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.plot(x, ypred, color = "red", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "OLs")
plt.plot(x ,ypred1, color = "black", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = 'b = 0')
plt.plot(x ,ypred2, color = "blue", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b1))
plt.plot(x ,ypred3, color = "grey", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b2))


plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * (np.sum(y - (m * x.ravel() - b2)))
loss_slope
# Out:
# -3770.9600783601068

# %%
step_size = loss_slope * lr
step_size
# Out:
# -3.770960078360107

# %%
b3 = b2 - step_size
b3
# Out:
# 9.532149086965827

# %%
ypred4 = ((58.63420764 * x) + b3).ravel()

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.plot(x, ypred, color = "red", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = "OLs")
plt.plot(x ,ypred1, color = "black", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label = 'b = 0')
plt.plot(x ,ypred2, color = "blue", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b1))
plt.plot(x ,ypred3, color = "grey", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b2))
plt.plot(x ,ypred4, color = "pink", marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 8, label='b = {}'.format(b3))


plt.legend()
plt.show()

# %%
# Iteration 4
loss_slope = -2 * (np.sum(y - (m * x.ravel() - b3)))
loss_slope
# Out:
# -4525.15209403213

# %%
step_size = loss_slope * lr
step_size
# Out:
# -4.52515209403213

# %%
b4 = b3 - step_size
b4
# Out:
# 14.057301180997957

# %%
b = 100
m = 58.63420764
lr = 0.001

epochs = 20

for i in range(epochs):
    loss_slope = -2 * (np.sum(y - (m * x.ravel() - b)))
    b = b - (lr * loss_slope)
    y_pred = (m * x) + b
    plt.figure(figsize = (12, 6))

    plt.plot(x , y_pred)

plt.figure(figsize = (12, 6))
plt.scatter(x, y)
# Out:
# <ipython-input-32-9a1aa9976045>:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize = (12, 6))

# %% [markdown]
# ## Case: Data with one feature & updating both the coefficent as well as slope after every epoch.

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
x, y = make_regression(n_samples = 100, n_features = 1, n_informative = 1, n_targets = 1,noise = 20, random_state = 13)

# %%
plt.figure(figsize = (12, 6))
plt.scatter(x, y, color = "seagreen")
plt.show()

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y,test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression
LinReg = LinearRegression()

# %%
LinReg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
b1 = LinReg.coef_
b0 = LinReg.intercept_
print("The 'Intercept' is: ", b0, "The 'Slope' is: ", b1)
# Out:
# The 'Intercept' is:  -2.271014426178382 The 'Slope' is:  [28.12597332]

# %%
ypred = LinReg.predict(xtest)

# %%
ypred
# Out:
# array([ 21.09901593,  18.03495551,  18.23747414,  -8.10292651,
#         15.72634513,  58.21059953, -15.03324179, -11.33105581,
#        -15.81005402,  -8.8082183 , -23.57512364,  14.78144416,
#         12.70150681, -23.8893975 , -22.30769518, -16.670531  ,
#         24.52827391, -16.98551717,  -3.88916883, -12.01966768])

# %%
from sklearn.metrics import r2_score
r2_score(ytest, ypred)
# Out:
# 0.6345158782661013

# %%
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.b0 = 100
        self.b1 = 100
        self.lr = learning_rate
        self.epochs = epochs
    def fit(self, x, y):
        for i in range(self.epochs):
            loss_slope_b0 = -2 * np.sum(y - self.b1 * x.ravel() - self.b0)
            loss_slope_b1 = -2 * np.sum((y - self.b1 * x.ravel() - self.b0) * x.ravel())
            
            self.b0 = self.b0 - (self.lr * loss_slope_b0)
            self.b1 = self.b1 - (self.lr * loss_slope_b1)
            print(self.b0, self.b1)
    def predict(self, x):
        return (self.b1 * x + self.b0)

# %%
gd = GDRegressor(0.001, 50)

# %%
gd.fit(xtrain, ytrain)
# Out:
# 83.05420777448876 88.2635327724942
# 68.9148485618292 78.44553028599468
# 57.11734683451273 70.23210141939336
# 47.27400276063838 63.36075634373176
# 39.06127556314429 57.61198282003544
# 32.209169802885185 52.80220394057465
# 26.492376923237906 48.77789062250741
# 21.7228818568748 45.410639383128014
# 17.74379246261546 42.59305703195364
# 14.424189600707859 40.23531991149258
# 11.654829078196707 38.26229704539482
# 9.344554595551497 36.611144711395234
# 7.417304114170102 35.22929513329181
# 5.809611503681167 34.072774671055605
# 4.468521554195111 33.10479749042437
# 3.3498499827688173 32.29458955508233
# 2.416731368594754 31.616405191652103
# 1.638407387808214 31.048704669118994
# 0.9892155951961394 30.57346640961941
# 0.44774557432037154 30.175611773596415
# -0.0038652351353961056 29.842523978591657
# -0.3805191439610245 29.563645733932322
# -0.6946485423998007 29.330142700673488
# -0.9566250493450611 29.13462199876368
# -1.1751009165930997 28.970896749541122
# ...

# %%
ypred = gd.predict(xtest)
from sklearn.metrics import r2_score
r2_score(ytest, ypred)
# Out:
# 0.6344610331198057

# %% [markdown]
# ## Case: When data has n features & updating both cofficient as well as slope after every epoch.

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x, y = load_diabetes(return_X_y = True)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
LinReg = LinearRegression()

# %%
LinReg.fit(xtest, ytest)
# Out:
# LinearRegression()

# %%
LinReg.coef_
# Out:
# array([ -51.3596091 , -350.58633147,  499.98566234,  271.14047859,
#        -107.91421056,   33.02028178, -320.46750911,  140.97718285,
#         236.06585847,  164.40018293])

# %%
LinReg.intercept_
# Out:
# 151.1724406398475

# %%
ypred = LinReg.predict(xtest)
r2_score(ytest, ypred)
# Out:
# 0.4872471349696138

# %%
class GDRegressor:
    
    def __init__(self, learning_rate = 0.01, epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
    def fit(self, xtrain, ytrain):     
        self.intercept_ = 0
        self.coef_ = np.ones(x.shape[1])
        
        for i in range(self.epochs):
            yhat = np.dot(xtrain, self.coef_) + self.intercept_
            intercept_der = -2 * np.mean(ytrain - yhat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)
            
            coef_der = -2 * np.dot((ytrain - yhat), xtrain) / xtrain.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)
        
            print(self.intercept_, self.coef_)
    
    def predict(self, xtest):
        return np.dot(xtest, self.coef_) + self.intercept_

# %%
gd = GDRegressor(epochs = 1000,learning_rate = 0.5)

# %%
gd.fit(xtrain, ytrain)
# Out:
# 150.46744512338387 [ 1.81850729  0.9779274   2.86819869  2.63831926  1.65142279  1.33631754
#  -0.05747848  2.08464245  3.10986288  2.18632165]
# 150.48030346036407 [ 2.64430407  1.16743583  5.03263969  4.31812137  2.43828069  1.9629816
#  -1.45294387  3.56249877  5.25062398  3.5065004 ]
# 150.4967713976613 [ 3.46114919  1.35114111  7.18349121  5.98625942  3.21435743  2.5789333
#  -2.8372879   5.02556904  7.3762332   4.81446066]
# 150.51308489992573 [ 4.26912602  1.52910775  9.32086971  7.64283093  3.97976529  3.1842907
#  -4.21061415  6.47400022  9.48682108  6.11031439]
# 150.52924546370264 [ 5.06831677  1.70139426 11.44488297  9.28793119  4.73461185  3.77916328
#  -5.57301659  7.90792778 11.5825158   7.3941689 ]
# 150.54525447862747 [ 5.8588029   1.86805862 13.55563779 10.9216547   5.4790037   4.36365951
#  -6.9245884   9.327486   13.66344445  8.66613056]
# 150.56111332178142 [ 6.64066514  2.0291583  15.65324007 12.54409509  6.21304643  4.93788683
# ...

# %%
ypred = gd.predict(xtest)

# %%
r2_score(ytest, ypred)
# Out:
# 0.4534524671450598

# %% [markdown]
# # Stochastic Gadient Descent

# %%
class SGDRegressor:
    
    def __init__(self, learning_rate = 0.01, epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
    
    def fit(self, xtrain, ytrain):     
        self.intercept_ = 0
        self.coef_ = np.ones(xtrain.shape[1])
        
        for i in range(self.epochs):
            for j in range(xtrain.shape[0]):
                idx = np.random.randint(0, xtrain.shape[0])
                
                yhat = np.dot(xtrain[idx], self.coef_) + self.intercept_
                intercept_der = -2 * (ytrain[idx] - yhat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((ytrain[idx] - yhat), xtrain[idx]) 
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
                print(self.intercept_, self.coef_)
    
    def predict(self, xtest):
        return np.dot(xtest, self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(learning_rate = 0.01, epochs = 10)

# %%
sgd.fit(xtrain, ytrain)
# Out:
# 1.265120664893995 [1.02519262 0.94352294 0.92669773 0.92749129 0.99801508 0.98407565
#  1.09413961 0.95003611 0.92260423 0.90431181]
# 6.420974964043731 [0.80947199 0.71335717 1.58933098 1.25327324 0.82675886 0.8158467
#  1.15510099 0.74641398 0.84011949 0.64248216]
# 7.720081404120431 [0.6984888  0.77919604 1.53646263 1.21012527 0.72104508 0.72545456
#  1.14654707 0.69510787 0.76503105 0.58727174]
# 11.020849418734622 [0.7282472  0.63184435 1.71876184 1.1914079  0.91115946 0.87306143
#  1.1369655  0.77181284 0.94882952 0.93919   ]
# 13.3402185484577 [0.81655929 0.74939026 1.73936576 1.29004969 0.81178019 0.82425673
#  1.044842   0.76580043 0.90680657 0.95590457]
# 15.212467936819511 [0.7450255  0.84427608 1.747926   1.35678385 0.79080981 0.83528154
#  0.95669184 0.83003517 0.93733351 0.95388685]
# 16.336085072796752 [0.64903444 0.90122113 1.70219934 1.3194645  0.69937634 0.75709999
#  0.94929342 0.78565973 0.87238837 0.90613451]
# ...

# %%
ypred = sgd.predict(xtest)

# %%
r2_score(ytest, ypred)
# Out:
# 0.26942997213993714

# %% [markdown]
# # Mini-Batch Gradient Descent

# %%
import random
class MBGDRegressor:
    
    def __init__(self, batch_size, learning_rate = 0.01, epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.batch_size = batch_size
        self.epochs = epochs
   
    def fit(self, xtrain, ytrain):     
        self.intercept_ = 0
        self.coef_ = np.ones(x.shape[1])
        
        for i in range(self.epochs):
            for j in range(int(xtrain.shape[0] / self.batch_size)):
                idx = random.sample(range(xtrain.shape[0]), self.batch_size)
                
                yhat = np.dot(xtrain[idx], self.coef_) + self.intercept_
                intercept_der = -2 * np.mean(ytrain[idx] - yhat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((ytrain[idx] - yhat), xtrain[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
                print(self.intercept_, self.coef_)
    
    def predict(self, xtest):
        return np.dot(xtest, self.coef_) + self.intercept_

# %%
mbgd = MBGDRegressor(batch_size = int(xtrain.shape[0] / 50), learning_rate = 0.01, epochs = 100)

# %%
mbgd.fit(xtrain, ytrain)
# Out:
# 2.4098644207167634 [1.19506954 1.39927253 1.30678554 0.9322424  1.18614082 1.36807794
#  0.5651814  1.53462121 1.09780544 1.22930894]
# 5.8223925116514295 [ 1.19809642  1.16058288  1.73623496  0.89309347  1.37878097  1.59630018
#  -0.05389681  2.20444961  1.79051694  2.05352179]
# 9.598046544185982 [ 2.16559187  1.23308945  2.67111527  2.26600932  2.18512869  2.40696499
#  -0.46938827  2.91803699  2.68641266  3.40339933]
# 11.986966244348505 [ 2.54465386  1.63993485  2.97806978  2.41883812  2.51106125  2.44365113
#  -0.64445017  3.41602264  3.21936381  4.28531431]
# 14.636694228598731 [ 2.3060856   2.11841866  2.85957214  2.89786768  2.14022562  2.11752977
#  -0.74756327  3.21232469  3.1667926   4.95957715]
# 17.305048551907866 [ 2.79393953  1.42503217  2.87086577  3.20636515  2.5349982   2.31836781
#  -1.43790767  4.18695381  3.94277746  5.41763369]
# 21.371751547697887 [ 3.32187438  2.05122511  3.86399298  4.28661374  2.1843291   2.10446065
# ...

# %%
ypred = mbgd.predict(xtest)

# %%
r2_score(ytest, ypred)
# Out:
# 0.4538799754919366
